# %% [markdown]
# <a href="https://colab.research.google.com/github/taetoo/EST-AI-Challengers-Repo/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World !")
# Out:
# Hello World !

# %%
import this

# %% [markdown]
# # 제목 1
# ## 제목 2
# ### 제목 3
#
# 기본 텍스트입니다.
#
# **굵은 텍스트**입니다.
#
# *기울임꼴 텍스트*입니다.
#
# - 목록 항목 1
# - 목록 항목 2
#   - 하위 항목 1
#   - 하위 항목 2
#
# 1. 번호 목록 1
# 2. 번호 목록 2
#
# [Google 링크](https://www.google.com)
#
# [!이미지 설명](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRkmQXQ2MkK4x6goB0Mi44NNZNfoxl4rtbc5dpV4-3n7E1uj1it_7fmG9MMUSuwww2naLSWsNIpOHAPVYWzs7qijpWkuLX0T6bla3jq5zwoZQ&s=10)
